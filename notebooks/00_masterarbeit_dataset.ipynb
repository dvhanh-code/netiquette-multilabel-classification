# %%
# %pip install env create --file=environment.yml
# Out:
# Usage:
#   pip3 install [options] <requirement specifier> [package-index-options] ...
#   pip3 install [options] -r <requirements file> [package-index-options] ...
#   pip3 install [options] [-e] <vcs project url> ...
#   pip3 install [options] [-e] <local project path> ...
#   pip3 install [options] <archive url/path> ...
#
# no such option: --file

# %%
pip install pyyaml

# %%
# !pip install convokit
from convokit import Corpus, download

path = download("wikipedia-politeness-corpus")
print(path)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.9/240.9 kB 3.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 40.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 14.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 43.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.8/235.8 kB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.4/608.4 kB 20.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 2.0 MB/s eta 0:00:00
# ...
#   Created wheel for convokit: filename=convokit-4.1.0-py3-none-any.whl size=292185 sha256=7b51d5e5a8fd814949b89f5a86c9ed7ba399b198dcfdea9194ce3435215c3d38
# ...

# %%
# !zip -r wikipedia-politeness-corpus.zip /root/.convokit/saved-corpora/wikipedia-politeness-corpus
# Out:
#   adding: root/.convokit/saved-corpora/wikipedia-politeness-corpus/ (stored 0%)
#   adding: root/.convokit/saved-corpora/wikipedia-politeness-corpus/index.json (deflated 40%)
#   adding: root/.convokit/saved-corpora/wikipedia-politeness-corpus/utterances.jsonl (deflated 86%)
#   adding: root/.convokit/saved-corpora/wikipedia-politeness-corpus/users.json (stored 0%)
#   adding: root/.convokit/saved-corpora/wikipedia-politeness-corpus/Annotations-bin.p (deflated 70%)
#   adding: root/.convokit/saved-corpora/wikipedia-politeness-corpus/conversations.json (deflated 74%)
#   adding: root/.convokit/saved-corpora/wikipedia-politeness-corpus/corpus.json (stored 0%)

# %%
from google.colab import files
files.download("wikipedia-politeness-corpus.zip")
